# %% [markdown]
# <a href="https://colab.research.google.com/github/DhairyasheelGithub/google-colab-import/blob/main/textMarkDown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Heading **Line**
#
#
# ```
# # This is formatted as code
# for item from list:
# print(item)
# ```

# %% [markdown]
# ![2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 1.   First
# 2.   Second
#
# ---
# ---
#
# *   Name
# *   Company
#
# ---
# ---
# ✈
# ⛳
